# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Fantasy Premier League data was taken from https://github.com/vaastav/Fantasy-Premier-League

# %%
data_upto_gw14 = pd.read_csv("https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2022-23/gws/merged_gw.csv")
data_upto_gw14.head()
# Out:
#                name position         team   xP  assists  bonus  bps  \
# 0    Nathan Redmond      MID  Southampton  1.5        0      0    3
# 1  Junior Stanislas      MID  Bournemouth  1.1        0      0    3
# 2     Armando Broja      FWD      Chelsea  2.0        0      0    3
# 3      Fabian Schär      DEF    Newcastle  2.4        0      3   43
# 4       Jonny Evans      DEF    Leicester  1.9        0      0   15
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0      403  ...             4     0.0             1
# 1             0         0.0       58  ...             2     0.0             1
# 2             0         0.3      150  ...             0    19.0             1
# 3             1        14.6      366  ...             2    25.0            15
# 4             0         1.3      249  ...             2     0.0             1
#
#    transfers_balance  transfers_in transfers_out  value  was_home  \
# ...

# %% [markdown]
# By intution, I think that players with good recent form are likely to be of relative low 'value' (which I will be measuring using the ratio of average points generated to cost (value column in this dataset).) as the cost of players is partially determined by the amount of inflows of the particular player from the squads of other fantasy league players, and I believe that many  I quickly get a rough idea how true the above statement is by plotting value (average points/cost) against the net out/in flow of a player from squads.
